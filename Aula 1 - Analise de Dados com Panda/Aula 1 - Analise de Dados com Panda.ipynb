# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

df.head(10)
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
# 5     2025.0               EN              FT       Data Engineer   80000
# 6     2025.0               SE              FT      Data Scientist  185000
# 7     2025.0               SE              FT      Data Scientist  148000
# 8     2025.0               MI              FT      Data Scientist  135000
# 9     2025.0               MI              FT      Data Scientist  108000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
# 5             USD          80000                 US             0
# 6             USD         185000                 US             0
# 7             USD         148000                 US             0
# 8             USD         135000                 CA             0
# 9             USD         108000                 CA             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               AU            M
# 3               AU            M
# 4               US            M
# 5               US            M
# 6               US            M
# 7               US            M
# 8               CA            M
# 9               CA            M

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape[0], df.shape[1]
print(f'Linhas: {linhas}')
print(f'Colunas: {colunas}')
# Out:
# Linhas: 133349
# Colunas: 11

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
novos_nomes = {
    'work_year': 'ano',
    'experience_level': 'nível_experiência',
    'employment_type': 'tipo_contrato',
    'job_title': 'cargo',
    'salary': 'salário',
    'salary_currency': 'moeda_salário',
    'salary_in_usd': 'salário_em_usd',
    'employee_residence': 'residência',
    'remote_ratio': 'taxa_remoto',
    'company_location': 'localização_empresa',
    'company_size': 'tamanho_empresa'
}

df = df.rename(columns=novos_nomes)

df.head(10)
# Out:
#       ano nível_experiência tipo_contrato               cargo  salário  \
# 0  2025.0            senior            FT  Solutions Engineer   214000
# 1  2025.0            senior            FT  Solutions Engineer   136000
# 2  2025.0             pleno            FT       Data Engineer   158800
# 3  2025.0             pleno            FT       Data Engineer   139200
# 4  2025.0            junior            FT       Data Engineer    90000
# 5  2025.0            junior            FT       Data Engineer    80000
# 6  2025.0            senior            FT      Data Scientist   185000
# 7  2025.0            senior            FT      Data Scientist   148000
# 8  2025.0             pleno            FT      Data Scientist   135000
# 9  2025.0             pleno            FT      Data Scientist   108000
#
#   moeda_salário  salário_em_usd residência  taxa_remoto localização_empresa  \
# 0           USD          214000         US          100                  US
# 1           USD          136000         US          100                  US
# 2           USD          158800         AU            0                  AU
# 3           USD          139200         AU            0                  AU
# 4           USD           90000         US            0                  US
# 5           USD           80000         US            0                  US
# 6           USD          185000         US            0                  US
# 7           USD          148000         US            0                  US
# 8           USD          135000         CA            0                  CA
# 9           USD          108000         CA            0                  CA
#
#   tamanho_empresa
# 0               M
# 1               M
# 2               M
# 3               M
# 4               M
# 5               M
# 6               M
# 7               M
# 8               M
# 9               M

# %%
df['nível_experiência'].value_counts()
# Out:
# nível_experiência
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df['tipo_contrato'].value_counts()
# Out:
# tipo_contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
df['taxa_remoto'].value_counts()
# Out:
# taxa_remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
nível_experiência = {
    'SE': 'senior',
    'MI': 'pleno',
    'EN': 'junior',
    'EX': 'executivo'
}
df['nível_experiência'] = df['nível_experiência'].replace(nível_experiência)
df['nível_experiência'].value_counts()
# Out:
# nível_experiência
# senior       77241
# pleno        40465
# junior       12443
# executivo     3200
# Name: count, dtype: int64

# %%
tipo_contrato = {
    'FT': 'integral',
    'PT': 'parcial',
    'CT': 'contrato',
    'FL': 'freelancer'
}
df['tipo_contrato'] = df['tipo_contrato'].replace(tipo_contrato)
df['tipo_contrato'].value_counts()
# Out:
# tipo_contrato
# integral      132563
# contrato         394
# parcial          376
# freelancer        16
# Name: count, dtype: int64

# %%
tamanho_empresa = {
    'L': 'grande',
    'S': 'pequena',
    'M':	'media'

}
df['tamanho_empresa'] = df['tamanho_empresa'].replace(tamanho_empresa)
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# media      129561
# grande       3574
# pequena       214
# Name: count, dtype: int64

# %%
mapa_trabalho = {
    0: 'presencial',
    100: 'remoto',
    50: 'hibrido'
}

df['taxa_remoto'] = df['taxa_remoto'].replace(mapa_trabalho)
df['taxa_remoto'].value_counts()
# Out:
# taxa_remoto
# presencial    105312
# remoto         27718
# hibrido          319
# Name: count, dtype: int64

# %%
df.head(10)
# Out:
#       ano nível_experiência tipo_contrato               cargo  salário  \
# 0  2025.0            senior      integral  Solutions Engineer   214000
# 1  2025.0            senior      integral  Solutions Engineer   136000
# 2  2025.0             pleno      integral       Data Engineer   158800
# 3  2025.0             pleno      integral       Data Engineer   139200
# 4  2025.0            junior      integral       Data Engineer    90000
# 5  2025.0            junior      integral       Data Engineer    80000
# 6  2025.0            senior      integral      Data Scientist   185000
# 7  2025.0            senior      integral      Data Scientist   148000
# 8  2025.0             pleno      integral      Data Scientist   135000
# 9  2025.0             pleno      integral      Data Scientist   108000
#
#   moeda_salário  salário_em_usd residência taxa_remoto localização_empresa  \
# 0           USD          214000         US      remoto                  US
# 1           USD          136000         US      remoto                  US
# 2           USD          158800         AU  presencial                  AU
# 3           USD          139200         AU  presencial                  AU
# 4           USD           90000         US  presencial                  US
# 5           USD           80000         US  presencial                  US
# 6           USD          185000         US  presencial                  US
# 7           USD          148000         US  presencial                  US
# 8           USD          135000         CA  presencial                  CA
# 9           USD          108000         CA  presencial                  CA
#
#   tamanho_empresa
# 0           media
# 1           media
# 2           media
# 3           media
# 4           media
# 5           media
# 6           media
# 7           media
# 8           media
# 9           media

# %%
df.describe(include='object')
# Out:
#        nível_experiência tipo_contrato           cargo moeda_salário  \
# count             133349        133349          133349        133349
# unique                 4             4             390            26
# top               senior      integral  Data Scientist           USD
# freq               77241        132563           17314        126140
#
#        residência taxa_remoto localização_empresa tamanho_empresa
# count      133349      133349              133349          133349
# unique        102           3                  95               3
# top            US  presencial                  US           media
# freq       119579      105312              119641          129561
